# %%
# June 2022
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
num_classes = len(np.unique(y_train))

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])

# %%
epochs = 100
batch_size = 128

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 14s 29ms/step - loss: 0.7033 - sparse_categorical_accuracy: 0.5983 - val_loss: 0.6948 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 2/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5647 - sparse_categorical_accuracy: 0.7212 - val_loss: 0.7098 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 3/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4981 - sparse_categorical_accuracy: 0.7517 - val_loss: 0.7315 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 4/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4709 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.7590 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 5/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4460 - sparse_categorical_accuracy: 0.7840 - val_loss: 0.7906 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 6/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4310 - sparse_categorical_accuracy: 0.7840 - val_loss: 0.7926 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 7/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4438 - sparse_categorical_accuracy: 0.7750 - val_loss: 0.8524 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 8/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4212 - sparse_categorical_accuracy: 0.7979 - val_loss: 0.8274 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 9/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4179 - sparse_categorical_accuracy: 0.7951 - val_loss: 0.7809 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 10/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4086 - sparse_categorical_accuracy: 0.7951 - val_loss: 0.8037 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 11/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4049 - sparse_categorical_accuracy: 0.7934 - val_loss: 0.8172 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 12/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3973 - sparse_categorical_accuracy: 0.8073 - val_loss: 0.8339 - val_sparse_categorical_accuracy: 0.4813 - lr: 0.0010
# Epoch 13/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3903 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.7963 - val_sparse_categorical_accuracy: 0.4799 - lr: 0.0010
# Epoch 14/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3927 - sparse_categorical_accuracy: 0.8024 - val_loss: 0.7651 - val_sparse_categorical_accuracy: 0.5270 - lr: 0.0010
# Epoch 15/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3857 - sparse_categorical_accuracy: 0.8229 - val_loss: 0.7411 - val_sparse_categorical_accuracy: 0.4785 - lr: 0.0010
# Epoch 16/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3808 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.6792 - val_sparse_categorical_accuracy: 0.5950 - lr: 0.0010
# Epoch 17/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3753 - sparse_categorical_accuracy: 0.8319 - val_loss: 0.6387 - val_sparse_categorical_accuracy: 0.6172 - lr: 0.0010
# Epoch 18/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3788 - sparse_categorical_accuracy: 0.8229 - val_loss: 0.6057 - val_sparse_categorical_accuracy: 0.6269 - lr: 0.0010
# Epoch 19/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.3682 - sparse_categorical_accuracy: 0.8319 - val_loss: 0.5778 - val_sparse_categorical_accuracy: 0.7226 - lr: 0.0010
# Epoch 20/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3677 - sparse_categorical_accuracy: 0.8347 - val_loss: 0.5454 - val_sparse_categorical_accuracy: 0.6755 - lr: 0.0010
# Epoch 21/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3673 - sparse_categorical_accuracy: 0.8229 - val_loss: 0.5742 - val_sparse_categorical_accuracy: 0.6671 - lr: 0.0010
# Epoch 22/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.3614 - sparse_categorical_accuracy: 0.8372 - val_loss: 0.3986 - val_sparse_categorical_accuracy: 0.8627 - lr: 0.0010
# Epoch 23/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3745 - sparse_categorical_accuracy: 0.8135 - val_loss: 0.4710 - val_sparse_categorical_accuracy: 0.7920 - lr: 0.0010
# Epoch 24/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3688 - sparse_categorical_accuracy: 0.8247 - val_loss: 0.4462 - val_sparse_categorical_accuracy: 0.7670 - lr: 0.0010
# Epoch 25/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3454 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.3830 - val_sparse_categorical_accuracy: 0.8710 - lr: 0.0010
# Epoch 26/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.3475 - sparse_categorical_accuracy: 0.8413 - val_loss: 0.3712 - val_sparse_categorical_accuracy: 0.8571 - lr: 0.0010
# Epoch 27/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3397 - sparse_categorical_accuracy: 0.8545 - val_loss: 0.4609 - val_sparse_categorical_accuracy: 0.7406 - lr: 0.0010
# Epoch 28/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3359 - sparse_categorical_accuracy: 0.8521 - val_loss: 0.5880 - val_sparse_categorical_accuracy: 0.6255 - lr: 0.0010
# Epoch 29/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3307 - sparse_categorical_accuracy: 0.8549 - val_loss: 0.4706 - val_sparse_categorical_accuracy: 0.7309 - lr: 0.0010
# Epoch 30/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3207 - sparse_categorical_accuracy: 0.8622 - val_loss: 0.5492 - val_sparse_categorical_accuracy: 0.6560 - lr: 0.0010
# Epoch 31/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3156 - sparse_categorical_accuracy: 0.8681 - val_loss: 1.1727 - val_sparse_categorical_accuracy: 0.5201 - lr: 0.0010
# Epoch 32/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3154 - sparse_categorical_accuracy: 0.8694 - val_loss: 0.9817 - val_sparse_categorical_accuracy: 0.5257 - lr: 0.0010
# Epoch 33/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3219 - sparse_categorical_accuracy: 0.8687 - val_loss: 0.8111 - val_sparse_categorical_accuracy: 0.5437 - lr: 0.0010
# Epoch 34/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3154 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.5145 - val_sparse_categorical_accuracy: 0.7018 - lr: 0.0010
# Epoch 35/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3315 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.3312 - val_sparse_categorical_accuracy: 0.8655 - lr: 0.0010
# Epoch 36/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3187 - sparse_categorical_accuracy: 0.8639 - val_loss: 1.3270 - val_sparse_categorical_accuracy: 0.5201 - lr: 0.0010
# Epoch 37/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3064 - sparse_categorical_accuracy: 0.8743 - val_loss: 0.8073 - val_sparse_categorical_accuracy: 0.6144 - lr: 0.0010
# Epoch 38/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.8795 - val_loss: 0.3036 - val_sparse_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 39/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3041 - sparse_categorical_accuracy: 0.8708 - val_loss: 0.5444 - val_sparse_categorical_accuracy: 0.7129 - lr: 0.0010
# Epoch 40/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2926 - sparse_categorical_accuracy: 0.8795 - val_loss: 0.4182 - val_sparse_categorical_accuracy: 0.7628 - lr: 0.0010
# Epoch 41/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2833 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.2960 - val_sparse_categorical_accuracy: 0.8724 - lr: 0.0010
# Epoch 42/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2912 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.2904 - val_sparse_categorical_accuracy: 0.8710 - lr: 0.0010
# Epoch 43/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2859 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.7270 - val_sparse_categorical_accuracy: 0.7129 - lr: 0.0010
# Epoch 44/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2718 - sparse_categorical_accuracy: 0.8962 - val_loss: 1.3433 - val_sparse_categorical_accuracy: 0.6865 - lr: 0.0010
# Epoch 45/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.8868 - val_loss: 2.3015 - val_sparse_categorical_accuracy: 0.6019 - lr: 0.0010
# Epoch 46/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2775 - sparse_categorical_accuracy: 0.8858 - val_loss: 1.5322 - val_sparse_categorical_accuracy: 0.6546 - lr: 0.0010
# Epoch 47/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2869 - sparse_categorical_accuracy: 0.8750 - val_loss: 1.8778 - val_sparse_categorical_accuracy: 0.6546 - lr: 0.0010
# Epoch 48/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2778 - sparse_categorical_accuracy: 0.8913 - val_loss: 3.4995 - val_sparse_categorical_accuracy: 0.4882 - lr: 0.0010
# Epoch 49/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2644 - sparse_categorical_accuracy: 0.8934 - val_loss: 3.1440 - val_sparse_categorical_accuracy: 0.5534 - lr: 0.0010
# Epoch 50/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2576 - sparse_categorical_accuracy: 0.9024 - val_loss: 2.7428 - val_sparse_categorical_accuracy: 0.5090 - lr: 0.0010
# Epoch 51/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2732 - sparse_categorical_accuracy: 0.8865 - val_loss: 1.8923 - val_sparse_categorical_accuracy: 0.6089 - lr: 0.0010
# Epoch 52/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2554 - sparse_categorical_accuracy: 0.8990 - val_loss: 3.4606 - val_sparse_categorical_accuracy: 0.5118 - lr: 0.0010
# Epoch 53/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2560 - sparse_categorical_accuracy: 0.8976 - val_loss: 3.9874 - val_sparse_categorical_accuracy: 0.4924 - lr: 0.0010
# Epoch 54/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.8844 - val_loss: 2.7106 - val_sparse_categorical_accuracy: 0.6352 - lr: 0.0010
# Epoch 55/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2675 - sparse_categorical_accuracy: 0.8997 - val_loss: 2.1684 - val_sparse_categorical_accuracy: 0.6477 - lr: 0.0010
# Epoch 56/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2564 - sparse_categorical_accuracy: 0.8938 - val_loss: 2.4863 - val_sparse_categorical_accuracy: 0.6214 - lr: 0.0010
# Epoch 57/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2573 - sparse_categorical_accuracy: 0.9000 - val_loss: 2.0132 - val_sparse_categorical_accuracy: 0.5922 - lr: 0.0010
# Epoch 58/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2629 - sparse_categorical_accuracy: 0.8955 - val_loss: 2.7504 - val_sparse_categorical_accuracy: 0.5368 - lr: 0.0010
# Epoch 59/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2543 - sparse_categorical_accuracy: 0.9010 - val_loss: 2.4389 - val_sparse_categorical_accuracy: 0.5853 - lr: 0.0010
# Epoch 60/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2577 - sparse_categorical_accuracy: 0.8976 - val_loss: 0.2268 - val_sparse_categorical_accuracy: 0.9140 - lr: 0.0010
# Epoch 61/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2403 - sparse_categorical_accuracy: 0.9108 - val_loss: 1.2395 - val_sparse_categorical_accuracy: 0.5381 - lr: 0.0010
# Epoch 62/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2396 - sparse_categorical_accuracy: 0.9090 - val_loss: 1.1263 - val_sparse_categorical_accuracy: 0.7018 - lr: 0.0010
# Epoch 63/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2515 - sparse_categorical_accuracy: 0.8920 - val_loss: 0.4044 - val_sparse_categorical_accuracy: 0.7712 - lr: 0.0010
# Epoch 64/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2539 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.2968 - val_sparse_categorical_accuracy: 0.8433 - lr: 0.0010
# Epoch 65/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2449 - sparse_categorical_accuracy: 0.9069 - val_loss: 0.6942 - val_sparse_categorical_accuracy: 0.6602 - lr: 0.0010
# Epoch 66/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2408 - sparse_categorical_accuracy: 0.9017 - val_loss: 0.5086 - val_sparse_categorical_accuracy: 0.7503 - lr: 0.0010
# Epoch 67/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2659 - sparse_categorical_accuracy: 0.8889 - val_loss: 1.7526 - val_sparse_categorical_accuracy: 0.5326 - lr: 0.0010
# Epoch 68/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2708 - sparse_categorical_accuracy: 0.8885 - val_loss: 1.6820 - val_sparse_categorical_accuracy: 0.5368 - lr: 0.0010
# Epoch 69/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2522 - sparse_categorical_accuracy: 0.8969 - val_loss: 3.0462 - val_sparse_categorical_accuracy: 0.5187 - lr: 0.0010
# Epoch 70/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2434 - sparse_categorical_accuracy: 0.9028 - val_loss: 1.7171 - val_sparse_categorical_accuracy: 0.5312 - lr: 0.0010
# Epoch 71/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2325 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.4027 - val_sparse_categorical_accuracy: 0.7989 - lr: 0.0010
# Epoch 72/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2249 - sparse_categorical_accuracy: 0.9118 - val_loss: 1.1990 - val_sparse_categorical_accuracy: 0.5617 - lr: 0.0010
# Epoch 73/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2441 - sparse_categorical_accuracy: 0.9014 - val_loss: 0.9651 - val_sparse_categorical_accuracy: 0.6338 - lr: 0.0010
# Epoch 74/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2419 - sparse_categorical_accuracy: 0.9066 - val_loss: 1.3119 - val_sparse_categorical_accuracy: 0.5506 - lr: 0.0010
# Epoch 75/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2344 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.4096 - val_sparse_categorical_accuracy: 0.7975 - lr: 0.0010
# Epoch 76/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2343 - sparse_categorical_accuracy: 0.9052 - val_loss: 1.8388 - val_sparse_categorical_accuracy: 0.5187 - lr: 0.0010
# Epoch 77/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2268 - sparse_categorical_accuracy: 0.9083 - val_loss: 1.3682 - val_sparse_categorical_accuracy: 0.5492 - lr: 0.0010
# Epoch 78/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2233 - sparse_categorical_accuracy: 0.9177 - val_loss: 1.4207 - val_sparse_categorical_accuracy: 0.5603 - lr: 0.0010
# Epoch 79/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2317 - sparse_categorical_accuracy: 0.9035 - val_loss: 0.6889 - val_sparse_categorical_accuracy: 0.6796 - lr: 0.0010
# Epoch 80/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2382 - sparse_categorical_accuracy: 0.9080 - val_loss: 3.4610 - val_sparse_categorical_accuracy: 0.5187 - lr: 0.0010
# Epoch 81/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2211 - sparse_categorical_accuracy: 0.9167 - val_loss: 2.1778 - val_sparse_categorical_accuracy: 0.5173 - lr: 5.0000e-04
# Epoch 82/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2321 - sparse_categorical_accuracy: 0.9080 - val_loss: 3.4673 - val_sparse_categorical_accuracy: 0.5187 - lr: 5.0000e-04
# Epoch 83/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9122 - val_loss: 2.9947 - val_sparse_categorical_accuracy: 0.5187 - lr: 5.0000e-04
# Epoch 84/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2136 - sparse_categorical_accuracy: 0.9187 - val_loss: 2.5290 - val_sparse_categorical_accuracy: 0.5187 - lr: 5.0000e-04
# Epoch 85/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2193 - sparse_categorical_accuracy: 0.9122 - val_loss: 2.2871 - val_sparse_categorical_accuracy: 0.5173 - lr: 5.0000e-04
# Epoch 86/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2122 - sparse_categorical_accuracy: 0.9139 - val_loss: 2.0003 - val_sparse_categorical_accuracy: 0.5243 - lr: 5.0000e-04
# Epoch 87/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2150 - sparse_categorical_accuracy: 0.9160 - val_loss: 1.5363 - val_sparse_categorical_accuracy: 0.5409 - lr: 5.0000e-04
# Epoch 88/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2140 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.2034 - val_sparse_categorical_accuracy: 0.9196 - lr: 5.0000e-04
# Epoch 89/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2103 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8308 - lr: 5.0000e-04
# Epoch 90/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2144 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.5419 - val_sparse_categorical_accuracy: 0.7406 - lr: 5.0000e-04
# Epoch 91/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2224 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.3936 - val_sparse_categorical_accuracy: 0.8183 - lr: 5.0000e-04
# Epoch 92/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2113 - sparse_categorical_accuracy: 0.9184 - val_loss: 1.6229 - val_sparse_categorical_accuracy: 0.6782 - lr: 5.0000e-04
# Epoch 93/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2114 - sparse_categorical_accuracy: 0.9153 - val_loss: 2.2368 - val_sparse_categorical_accuracy: 0.6630 - lr: 5.0000e-04
# Epoch 94/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2108 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.2277 - val_sparse_categorical_accuracy: 0.8988 - lr: 5.0000e-04
# Epoch 95/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2181 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.3376 - val_sparse_categorical_accuracy: 0.8322 - lr: 5.0000e-04
# Epoch 96/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2084 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.2404 - val_sparse_categorical_accuracy: 0.8932 - lr: 5.0000e-04
# Epoch 97/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2080 - sparse_categorical_accuracy: 0.9212 - val_loss: 1.5104 - val_sparse_categorical_accuracy: 0.6713 - lr: 5.0000e-04
# Epoch 98/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2190 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.2120 - val_sparse_categorical_accuracy: 0.9085 - lr: 5.0000e-04
# Epoch 99/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2158 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.9339 - val_sparse_categorical_accuracy: 0.7060 - lr: 5.0000e-04
# Epoch 100/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2104 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.5368 - val_sparse_categorical_accuracy: 0.7490 - lr: 5.0000e-04

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_train, y_train)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 113/113 [==============================] - 0s 2ms/step - loss: 0.2099 - sparse_categorical_accuracy: 0.9164
# Test accuracy 0.9164121150970459
# Test loss 0.209928497672081

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
