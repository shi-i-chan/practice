# %%
import os
import cv2
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#plt.style.use("ggplot")
plt.style.use('seaborn')
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
def im_read(im_width:int, im_height:int, encoding:str, n_examples:int):
  inputs = []
  outputs = []
  for i in range(1, n_examples + 1):
    inputs.append(cv2.resize(cv2.cvtColor(cv2.imread('in ' + str(i) + '.jpg'),
                                          getattr(cv2,'COLOR_BGR2' + encoding)),
                             (im_width, im_height))
                  / 255)
    outputs.append((cv2.resize(cv2.cvtColor(cv2.imread('out ' + str(i) + '.jpg'),
                                           cv2.COLOR_BGR2GRAY),
                              (im_width, im_height))
                  / 255).reshape(im_width, im_height, 1))
  return np.array(inputs), np.array(outputs)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters,
               kernel_size=(kernel_size, kernel_size), 
               kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters,
               kernel_size=(kernel_size, kernel_size),
               kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}

encodings = ['RGB', 'HSV', 'LAB', 'XYZ', 'YUV']

def check_encodings(encodings, n_samples=10, epoch=10):
  encodings_results = []
  im_height, im_width = 128, 128
  for encoding in encodings:
    inputs, outputs = im_read(im_height, im_width,
                              encoding,
                              n_samples)
    X_train, X_valid, y_train, y_valid = train_test_split(inputs, outputs,
                                                          test_size=0.2, random_state=2018)
    input_img = Input((im_height, im_width, 3),
                      name='img')
    model = get_unet(input_img, 
                     n_filters=16,
                     dropout=0.05,
                     batchnorm=False)
    model.compile(optimizer=Adam(),
                  loss="binary_crossentropy",
                  metrics=[tf.keras.metrics.BinaryCrossentropy()])
    result = model.fit(X_train, y_train,
                       epochs=epoch,
                       verbose=0,
                       validation_data=(X_valid, y_valid))
    encodings_results.append(result)
    print(encoding + " pass")
  return encodings_results
  
# plot encodings
def encodings_learning_curve(history, labels, title, save=False): #################
  colors = ['b', 'g', 'c', 'y', 'm']
  fig = plt.figure(figsize=(8,6))
  for i in range(len(history)):
    plt.plot([1 - loss for loss in history[i].history["loss"]],
            colors[i] + '--',
            label=labels[i] + ' train')
    plt.plot([1 - val_loss for val_loss in history[i].history["val_loss"]],
            colors[i],
            label=labels[i] + ' test')
  plt.title(title)
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.ylim(0, 1)
  plt.legend(loc='lower right', 
             prop={'size': 15}, 
             fontsize='xx-large',
             ncol=2,handleheight=2.4,
             labelspacing=0.05)
  if save:
    plt.savefig(title + '_epoch_l_c.png', dpi=300)

enc_res = check_encodings(encodings, n_samples=16, epoch=40)
# Out:
# RGB pass
# HSV pass
# LAB pass
# XYZ pass
# YUV pass

# %%
encodings_learning_curve(enc_res, encodings, "Encodings", save=False)

# %%
def KFold(inputs=None, outputs=None,  model=None, k_block=5, epoch=50, verbose=True):
  set_length = len(inputs)
  step_length = int(set_length/k_block)
  train_scores = []
  test_scores = []
  for index in range(k_block):
    x_test = np.array(inputs[index*step_length:step_length*index + step_length])
    y_test = np.array(outputs[index*step_length:step_length*index + step_length])
    x_train = np.array(inputs[0:index*step_length] + inputs[step_length*index + step_length:set_length])
    y_train = np.array(outputs[0:index*step_length] + outputs[step_length*index + step_length:set_length])
    input_img = Input((128, 128, 3), name='img')
    model = get_unet(input_img,
                     n_filters=16,
                     dropout=0.05,
                     batchnorm=False)
    model.compile(optimizer=Adam(),
                  loss="binary_crossentropy", 
                  metrics=[tf.keras.metrics.BinaryCrossentropy()])
    fit_model = model.fit(x_train, y_train,
                    epochs=epoch,
                    verbose=verbose,
                    validation_data=(x_test, y_test))
    train_scores.append(1 - fit_model.history["loss"][-1])
    test_scores.append(1 - fit_model.history["val_loss"][-1])
    if verbose:
      print("Block: 1, test accuracy : {0}, train accuracy : {1}\n".format(test_scores[-1],
                                                                           train_scores[-1]))
  if verbose:
    print("Cross-validation accuracy: ", np.mean(test_scores))
  return train_scores, test_scores

# %%
def num_examples_learning_curve(param_range, k_block=5, epoch=15):
  length = len(param_range)
  train_score = [None]*length
  test_score = [None]*length
  for itter in range(length):
    inputs, outputs = im_read(128, 128,
                              "HSV",
                              param_range[itter])
    train_scores, test_scores = KFold(list(inputs),
                                      list(outputs),
                                      k_block=k_block, 
                                      epoch=epoch,
                                      verbose=0)
    
    train_score[itter] = train_scores
    test_score[itter] = test_scores
    #print("Pass " + str(itter) + " examples")
  return train_score, test_score

param_range = list(range(10, 16))

t_score, v_score = num_examples_learning_curve(param_range, k_block=5, epoch=1)

# %%
def plot_learning_curve(train_scores, test_scores, param_name, param_range):
  #train_scores.shape = [n_param_value][k_accuracy_values]

  train_mean = np.mean(train_scores, axis=1)
  train_std = np.std(train_scores, axis=1)
  test_mean = np.mean(test_scores, axis=1)
  test_std = np.std(test_scores, axis=1)

  plt.figure(figsize=(10, 8))
  plt.plot(param_range,
          train_mean,
          color='blue',
          marker='o',
          markersize=5,
          label='train accuracy')
  plt.fill_between(param_range,
                  train_mean + train_std,
                  train_mean - train_std,
                  alpha=0.15,
                  color="blue")
  plt.plot(param_range,
          test_mean,
          color='green',
          marker='s',
          markersize=5,
          label='test accuracy')
  plt.fill_between(param_range,
                  test_mean + test_std,
                  test_mean - test_std,
                  alpha=0.15,
                  color='green')
  plt.grid()
  plt.legend(loc='lower right', prop={'size': 15})
  plt.xlabel(param_name)
  plt.ylabel("Accuracy")
  #plt.ylim(0.5, 0.8)
  plt.savefig('LC_num_samples.png', dpi=300)
  plt.show()

plot_learning_curve(t_score, v_score, "Number of training samples", param_range)

# %%
im_height = 128
im_width = 128

input_img = Input((im_height, im_width, 3), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=False)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=[tf.keras.metrics.BinaryCrossentropy()])

# %%
inputs, outputs = im_read(128, 128, "HSV", 16)
X_train, X_valid, y_train, y_valid = train_test_split(inputs, outputs, test_size=0.2, random_state=2018)

# %%
results = model.fit(X_train, y_train, epochs=100,
                   validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 496ms/step - loss: 0.5460 - binary_crossentropy: 0.5460 - val_loss: 0.4889 - val_binary_crossentropy: 0.4889
# Epoch 2/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.4914 - binary_crossentropy: 0.4914 - val_loss: 0.4474 - val_binary_crossentropy: 0.4474
# Epoch 3/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.4493 - binary_crossentropy: 0.4493 - val_loss: 0.4095 - val_binary_crossentropy: 0.4095
# Epoch 4/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.4110 - binary_crossentropy: 0.4110 - val_loss: 0.3767 - val_binary_crossentropy: 0.3767
# Epoch 5/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.3788 - binary_crossentropy: 0.3788 - val_loss: 0.3482 - val_binary_crossentropy: 0.3482
# Epoch 6/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.3526 - binary_crossentropy: 0.3526 - val_loss: 0.3251 - val_binary_crossentropy: 0.3251
# Epoch 7/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.3329 - binary_crossentropy: 0.3329 - val_loss: 0.3087 - val_binary_crossentropy: 0.3087
# Epoch 8/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3204 - binary_crossentropy: 0.3204 - val_loss: 0.2990 - val_binary_crossentropy: 0.2990
# Epoch 9/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3156 - binary_crossentropy: 0.3156 - val_loss: 0.3153 - val_binary_crossentropy: 0.3153
# Epoch 10/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.3284 - binary_crossentropy: 0.3284 - val_loss: 0.3076 - val_binary_crossentropy: 0.3076
# Epoch 11/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3299 - binary_crossentropy: 0.3299 - val_loss: 0.3012 - val_binary_crossentropy: 0.3012
# Epoch 12/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.3205 - binary_crossentropy: 0.3205 - val_loss: 0.2924 - val_binary_crossentropy: 0.2924
# Epoch 13/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.3109 - binary_crossentropy: 0.3109 - val_loss: 0.2886 - val_binary_crossentropy: 0.2886
# Epoch 14/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.3074 - binary_crossentropy: 0.3074 - val_loss: 0.2882 - val_binary_crossentropy: 0.2882
# Epoch 15/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3078 - binary_crossentropy: 0.3078 - val_loss: 0.2892 - val_binary_crossentropy: 0.2892
# Epoch 16/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.3094 - binary_crossentropy: 0.3094 - val_loss: 0.2893 - val_binary_crossentropy: 0.2893
# Epoch 17/100
# 1/1 [==============================] - 0s 196ms/step - loss: 0.3099 - binary_crossentropy: 0.3099 - val_loss: 0.2882 - val_binary_crossentropy: 0.2882
# Epoch 18/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.3087 - binary_crossentropy: 0.3087 - val_loss: 0.2865 - val_binary_crossentropy: 0.2865
# Epoch 19/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3071 - binary_crossentropy: 0.3071 - val_loss: 0.2850 - val_binary_crossentropy: 0.2850
# Epoch 20/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3057 - binary_crossentropy: 0.3057 - val_loss: 0.2843 - val_binary_crossentropy: 0.2843
# Epoch 21/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.3050 - binary_crossentropy: 0.3050 - val_loss: 0.2844 - val_binary_crossentropy: 0.2844
# Epoch 22/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3049 - binary_crossentropy: 0.3049 - val_loss: 0.2847 - val_binary_crossentropy: 0.2847
# Epoch 23/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.3052 - binary_crossentropy: 0.3052 - val_loss: 0.2848 - val_binary_crossentropy: 0.2848
# Epoch 24/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.3051 - binary_crossentropy: 0.3051 - val_loss: 0.2845 - val_binary_crossentropy: 0.2845
# Epoch 25/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.3050 - binary_crossentropy: 0.3050 - val_loss: 0.2838 - val_binary_crossentropy: 0.2838
# Epoch 26/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.3044 - binary_crossentropy: 0.3044 - val_loss: 0.2831 - val_binary_crossentropy: 0.2831
# Epoch 27/100
# 1/1 [==============================] - 0s 210ms/step - loss: 0.3039 - binary_crossentropy: 0.3039 - val_loss: 0.2825 - val_binary_crossentropy: 0.2825
# Epoch 28/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.3035 - binary_crossentropy: 0.3035 - val_loss: 0.2823 - val_binary_crossentropy: 0.2823
# Epoch 29/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.3034 - binary_crossentropy: 0.3034 - val_loss: 0.2822 - val_binary_crossentropy: 0.2822
# Epoch 30/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.3033 - binary_crossentropy: 0.3033 - val_loss: 0.2821 - val_binary_crossentropy: 0.2821
# Epoch 31/100
# 1/1 [==============================] - 0s 193ms/step - loss: 0.3031 - binary_crossentropy: 0.3031 - val_loss: 0.2820 - val_binary_crossentropy: 0.2820
# Epoch 32/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.3028 - binary_crossentropy: 0.3028 - val_loss: 0.2817 - val_binary_crossentropy: 0.2817
# Epoch 33/100
# 1/1 [==============================] - 0s 196ms/step - loss: 0.3025 - binary_crossentropy: 0.3025 - val_loss: 0.2816 - val_binary_crossentropy: 0.2816
# Epoch 34/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3023 - binary_crossentropy: 0.3023 - val_loss: 0.2814 - val_binary_crossentropy: 0.2814
# Epoch 35/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3020 - binary_crossentropy: 0.3020 - val_loss: 0.2814 - val_binary_crossentropy: 0.2814
# Epoch 36/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.3019 - binary_crossentropy: 0.3019 - val_loss: 0.2814 - val_binary_crossentropy: 0.2814
# Epoch 37/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3018 - binary_crossentropy: 0.3018 - val_loss: 0.2813 - val_binary_crossentropy: 0.2813
# Epoch 38/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.3015 - binary_crossentropy: 0.3015 - val_loss: 0.2813 - val_binary_crossentropy: 0.2813
# Epoch 39/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3013 - binary_crossentropy: 0.3013 - val_loss: 0.2811 - val_binary_crossentropy: 0.2811
# Epoch 40/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3010 - binary_crossentropy: 0.3010 - val_loss: 0.2810 - val_binary_crossentropy: 0.2810
# Epoch 41/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.3006 - binary_crossentropy: 0.3006 - val_loss: 0.2810 - val_binary_crossentropy: 0.2810
# Epoch 42/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.3002 - binary_crossentropy: 0.3002 - val_loss: 0.2815 - val_binary_crossentropy: 0.2815
# Epoch 43/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2994 - binary_crossentropy: 0.2994 - val_loss: 0.2816 - val_binary_crossentropy: 0.2816
# Epoch 44/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2991 - binary_crossentropy: 0.2991 - val_loss: 0.2876 - val_binary_crossentropy: 0.2876
# Epoch 45/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.3022 - binary_crossentropy: 0.3022 - val_loss: 0.2828 - val_binary_crossentropy: 0.2828
# Epoch 46/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.2995 - binary_crossentropy: 0.2995 - val_loss: 0.2831 - val_binary_crossentropy: 0.2831
# Epoch 47/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2998 - binary_crossentropy: 0.2998 - val_loss: 0.2829 - val_binary_crossentropy: 0.2829
# Epoch 48/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.2965 - binary_crossentropy: 0.2965 - val_loss: 0.2852 - val_binary_crossentropy: 0.2852
# Epoch 49/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2984 - binary_crossentropy: 0.2984 - val_loss: 0.2844 - val_binary_crossentropy: 0.2844
# Epoch 50/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2972 - binary_crossentropy: 0.2972 - val_loss: 0.2830 - val_binary_crossentropy: 0.2830
# Epoch 51/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.2959 - binary_crossentropy: 0.2959 - val_loss: 0.2834 - val_binary_crossentropy: 0.2834
# Epoch 52/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.2969 - binary_crossentropy: 0.2969 - val_loss: 0.2840 - val_binary_crossentropy: 0.2840
# Epoch 53/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.2946 - binary_crossentropy: 0.2946 - val_loss: 0.2869 - val_binary_crossentropy: 0.2869
# Epoch 54/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2950 - binary_crossentropy: 0.2950 - val_loss: 0.2876 - val_binary_crossentropy: 0.2876
# Epoch 55/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2942 - binary_crossentropy: 0.2942 - val_loss: 0.2863 - val_binary_crossentropy: 0.2863
# Epoch 56/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.2939 - binary_crossentropy: 0.2939 - val_loss: 0.2865 - val_binary_crossentropy: 0.2865
# Epoch 57/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2937 - binary_crossentropy: 0.2937 - val_loss: 0.2875 - val_binary_crossentropy: 0.2875
# Epoch 58/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.2926 - binary_crossentropy: 0.2926 - val_loss: 0.2874 - val_binary_crossentropy: 0.2874
# Epoch 59/100
# 1/1 [==============================] - 0s 193ms/step - loss: 0.2929 - binary_crossentropy: 0.2929 - val_loss: 0.2847 - val_binary_crossentropy: 0.2847
# Epoch 60/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.2916 - binary_crossentropy: 0.2916 - val_loss: 0.2834 - val_binary_crossentropy: 0.2834
# Epoch 61/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.2915 - binary_crossentropy: 0.2915 - val_loss: 0.2809 - val_binary_crossentropy: 0.2809
# Epoch 62/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2905 - binary_crossentropy: 0.2905 - val_loss: 0.2823 - val_binary_crossentropy: 0.2823
# Epoch 63/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.2893 - binary_crossentropy: 0.2893 - val_loss: 0.2849 - val_binary_crossentropy: 0.2849
# Epoch 64/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.2888 - binary_crossentropy: 0.2888 - val_loss: 0.2843 - val_binary_crossentropy: 0.2843
# Epoch 65/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2929 - binary_crossentropy: 0.2929 - val_loss: 0.2903 - val_binary_crossentropy: 0.2903
# Epoch 66/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2926 - binary_crossentropy: 0.2926 - val_loss: 0.2872 - val_binary_crossentropy: 0.2872
# Epoch 67/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.2886 - binary_crossentropy: 0.2886 - val_loss: 0.2814 - val_binary_crossentropy: 0.2814
# Epoch 68/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2895 - binary_crossentropy: 0.2895 - val_loss: 0.2802 - val_binary_crossentropy: 0.2802
# Epoch 69/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.2895 - binary_crossentropy: 0.2895 - val_loss: 0.2814 - val_binary_crossentropy: 0.2814
# Epoch 70/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.2882 - binary_crossentropy: 0.2882 - val_loss: 0.2837 - val_binary_crossentropy: 0.2837
# Epoch 71/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.2886 - binary_crossentropy: 0.2886 - val_loss: 0.2849 - val_binary_crossentropy: 0.2849
# Epoch 72/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.2882 - binary_crossentropy: 0.2882 - val_loss: 0.2860 - val_binary_crossentropy: 0.2860
# Epoch 73/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2875 - binary_crossentropy: 0.2875 - val_loss: 0.2871 - val_binary_crossentropy: 0.2871
# Epoch 74/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.2880 - binary_crossentropy: 0.2880 - val_loss: 0.2869 - val_binary_crossentropy: 0.2869
# Epoch 75/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.2870 - binary_crossentropy: 0.2870 - val_loss: 0.2862 - val_binary_crossentropy: 0.2862
# Epoch 76/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2868 - binary_crossentropy: 0.2868 - val_loss: 0.2846 - val_binary_crossentropy: 0.2846
# Epoch 77/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.2864 - binary_crossentropy: 0.2864 - val_loss: 0.2816 - val_binary_crossentropy: 0.2816
# Epoch 78/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2863 - binary_crossentropy: 0.2863 - val_loss: 0.2817 - val_binary_crossentropy: 0.2817
# Epoch 79/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2860 - binary_crossentropy: 0.2860 - val_loss: 0.2843 - val_binary_crossentropy: 0.2843
# Epoch 80/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2855 - binary_crossentropy: 0.2855 - val_loss: 0.2867 - val_binary_crossentropy: 0.2867
# Epoch 81/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.2852 - binary_crossentropy: 0.2852 - val_loss: 0.2871 - val_binary_crossentropy: 0.2871
# Epoch 82/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2852 - binary_crossentropy: 0.2852 - val_loss: 0.2874 - val_binary_crossentropy: 0.2874
# Epoch 83/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2849 - binary_crossentropy: 0.2849 - val_loss: 0.2875 - val_binary_crossentropy: 0.2875
# Epoch 84/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2844 - binary_crossentropy: 0.2844 - val_loss: 0.2869 - val_binary_crossentropy: 0.2869
# Epoch 85/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2842 - binary_crossentropy: 0.2842 - val_loss: 0.2859 - val_binary_crossentropy: 0.2859
# Epoch 86/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.2844 - binary_crossentropy: 0.2844 - val_loss: 0.2864 - val_binary_crossentropy: 0.2864
# Epoch 87/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2840 - binary_crossentropy: 0.2840 - val_loss: 0.2867 - val_binary_crossentropy: 0.2867
# Epoch 88/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.2835 - binary_crossentropy: 0.2835 - val_loss: 0.2871 - val_binary_crossentropy: 0.2871
# Epoch 89/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2835 - binary_crossentropy: 0.2835 - val_loss: 0.2875 - val_binary_crossentropy: 0.2875
# Epoch 90/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.2834 - binary_crossentropy: 0.2834 - val_loss: 0.2859 - val_binary_crossentropy: 0.2859
# Epoch 91/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.2834 - binary_crossentropy: 0.2834 - val_loss: 0.2861 - val_binary_crossentropy: 0.2861
# Epoch 92/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.2828 - binary_crossentropy: 0.2828 - val_loss: 0.2867 - val_binary_crossentropy: 0.2867
# Epoch 93/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2830 - binary_crossentropy: 0.2830 - val_loss: 0.2868 - val_binary_crossentropy: 0.2868
# Epoch 94/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2829 - binary_crossentropy: 0.2829 - val_loss: 0.2872 - val_binary_crossentropy: 0.2872
# Epoch 95/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2826 - binary_crossentropy: 0.2826 - val_loss: 0.2868 - val_binary_crossentropy: 0.2868
# Epoch 96/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2828 - binary_crossentropy: 0.2828 - val_loss: 0.2860 - val_binary_crossentropy: 0.2860
# Epoch 97/100
# 1/1 [==============================] - 0s 193ms/step - loss: 0.2823 - binary_crossentropy: 0.2823 - val_loss: 0.2856 - val_binary_crossentropy: 0.2856
# Epoch 98/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.2825 - binary_crossentropy: 0.2825 - val_loss: 0.2866 - val_binary_crossentropy: 0.2866
# Epoch 99/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.2822 - binary_crossentropy: 0.2822 - val_loss: 0.2873 - val_binary_crossentropy: 0.2873
# Epoch 100/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2820 - binary_crossentropy: 0.2820 - val_loss: 0.2873 - val_binary_crossentropy: 0.2873

# %%
def epoch_learning_curve(results):
  train = [1 - i for i in results.history["loss"]]
  test = [1 - i for i in results.history["val_loss"]]
  length = len(train)

  fig = plt.figure(figsize=(12,6))

  plt.plot(train, label='Train accuracy')
  plt.plot(test, label='Test accuracy')

  plt.title('Learing curves')
  plt.legend(loc='lower right')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.ylim(0, 1)
  #plt.savefig('LC.png', dpi=300)

epoch_learning_curve(results)

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(121)
plt.imshow(X_train[0])
plt.axis('off')
plt.title('Input HSV image')

plt.subplot(122)
plt.imshow(y_train[0].reshape(128, 128))
plt.axis('off')
plt.title('Output WB image')
#plt.savefig('in out.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Output WB image')

# %%
fig = plt.figure()
plt.hist(model.predict(X_train, verbose=0)[0].reshape(128*128),
         color = 'blue',
         edgecolor = 'black')
plt.xlabel('gray intensity')
plt.ylabel('Number of pixels')
#plt.savefig('hist.png', dpi=300)
# Out:
# Text(0, 0.5, 'Number of pixels')

# %%
def show_results(test_data, model):
  preds = model.predict(test_data, verbose=0)
  length = len(test_data)
  for i in range(length):
    prediction = preds[i].reshape(128*128)
    color_image = np.zeros((128*128, 3))
    for pixel in range(128*128):
      if prediction[pixel] > 0.9:
        color_image[pixel] = np.array((1,
                                       1,
                                       1))
        #color_image[pixel] = np.array(1)
      if prediction[pixel] > 0.45 and prediction[pixel] < 0.9:
        color_image[pixel] = np.array((0.09019607843137255,
                                       0.7450980392156863,
                                       0.8117647058823529))
        #color_image[pixel] = np.array(0.29803922)
        
      if prediction[pixel] < 0.45:
        color_image[pixel] = np.array((0.9058823529411765,
                                       0.5411764705882353,
                                       0.7647058823529411))
        #color_image[pixel] = np.array(0)
    fig = plt.figure(figsize=(12,6))
    plt.gray()
    plt.subplot(131)
    plt.imshow(test_data[i].reshape(128, 128, 3))
    plt.title('Input image')
    plt.axis('off')

    plt.subplot(132)
    plt.imshow(preds[i].reshape(128, 128))
    plt.title('Output image')
    plt.axis('off')

    plt.subplot(133)
    plt.imshow((color_image.reshape(128, 128, 3) * 255).astype(np.uint8))
    plt.title('Repaint')
    plt.axis('off')
    #plt.savefig('path.png', dpi=300)

# %%
show_results(X_train, model)

# %%
show_results(X_valid, model)
